# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_excel(r"E:\durga79\EXCEL_FILES\anna_canteen.xlsx",sheet_name="Sheet2")

# %%
df
# Out:
#    No_of_Customer No_of_food_delivery_units No_of_Anna_Canteens  \
# 0             300                        RK           Canteen-1
# 1             300                        RK           Canteen-2
# 2             300                        RK           Canteen-3
# 3             300                        RK           Canteen-4
# 4             300                        RK           Canteen-5
# 5             300                  nakshtra           Canteen-6
# 6             300                  nakshtra           Canteen-7
# 7             300                  nakshtra           Canteen-8
# 8             300                  nakshtra           Canteen-9
# 9             300                  nakshtra          Canteen-10
#
#    Total_Available_food_plates  No_of_Plates_Consumed  \
# 0                          320                    300
# 1                          320                    300
# 2                          320                    250
# ...

# %%
df.head()
# Out:
#    No_of_Customer No_of_food_delivery_units No_of_Anna_Canteens  \
# 0             300                        RK           Canteen-1
# 1             300                        RK           Canteen-2
# 2             300                        RK           Canteen-3
# 3             300                        RK           Canteen-4
# 4             300                        RK           Canteen-5
#
#    Total_Available_food_plates  No_of_Plates_Consumed  \
# 0                          320                    300
# 1                          320                    300
# 2                          320                    250
# 3                          320                    300
# 4                          320                    300
#
#    No_of_feedbacks_received  rating Food_weight_Gow_Down  \
# 0                       120       4                270kg
# 1                       160       4                270kg
# 2                        90       3                270kg
# ...

# %%
df.tail()
# Out:
#    No_of_Customer No_of_food_delivery_units No_of_Anna_Canteens  \
# 5             300                  nakshtra           Canteen-6
# 6             300                  nakshtra           Canteen-7
# 7             300                  nakshtra           Canteen-8
# 8             300                  nakshtra           Canteen-9
# 9             300                  nakshtra          Canteen-10
#
#    Total_Available_food_plates  No_of_Plates_Consumed  \
# 5                          320                    270
# 6                          320                    300
# 7                          320                    300
# 8                          320                    190
# 9                          320                    300
#
#    No_of_feedbacks_received  rating Food_weight_Gow_Down  \
# 5                       250       4                270kg
# 6                       250       5                270kg
# 7                       180       4                270kg
# ...

# %%
df.dtypes
# Out:
# No_of_Customer                  int64
# No_of_food_delivery_units      object
# No_of_Anna_Canteens            object
# Total_Available_food_plates     int64
# No_of_Plates_Consumed           int64
# No_of_feedbacks_received        int64
# rating                          int64
# Food_weight_Gow_Down           object
# Food_weight_Anna_Canteen       object
# No_of_Donations                 int64
# Total_Donation_Amount           int64
# no_of_employs                   int64
# Total_generated_tokens          int64
# dtype: object

# %%
df.columns
# Out:
# Index(['No_of_Customer', 'No_of_food_delivery_units', 'No_of_Anna_Canteens',
#        'Total_Available_food_plates', 'No_of_Plates_Consumed',
#        'No_of_feedbacks_received', 'rating', 'Food_weight_Gow_Down',
#        'Food_weight_Anna_Canteen', 'No_of_Donations', 'Total_Donation_Amount',
#        'no_of_employs', 'Total_generated_tokens'],
#       dtype='object')

# %%
df.plot(kind='bar',
        x='No_of_Anna_Canteens',
        y='Total_Donation_Amount',
        color='green')

plt.title('anna_canteen_donations')


plt.show()

# %%
df.plot(kind='scatter',
        x='No_of_Plates_Consumed',
        y='No_of_Anna_Canteens',
        color='blue'
     )


plt.title('About food plates')


plt.show()

# %%
df.set_index('No_of_Anna_Canteens', inplace=True)
df.plot(kind='pie', y='rating',autopct='%1.1f%%', startangle=150,legend=False)
plt.title('canteen ratings')
plt.show()

# %%
line=df.plot.line()

# %%
df.hist()
plt.show()

# %%
df['rating'].plot()
# Out:
# <Axes: xlabel='No_of_Anna_Canteens'>

# %%
df.plot.bar()
# Out:
# <Axes: xlabel='No_of_Anna_Canteens'>

# %%
df.plot(x='Total_Available_food_plates', y='No_of_Plates_Consumed')
# Out:
# <Axes: xlabel='Total_Available_food_plates'>

# %%
df.plot(x='', kind='area', stacked=False)
plt.title('no of Gow_Downs')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()
